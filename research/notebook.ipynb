# %% [markdown]
# # Lab 3 - Build a Google Search with Gemini AI
#
# reference:
#
# hugging face space [Google Search with Gemini AI](https://huggingface.co/spaces/Rahatara/Gemini_2_Web_Search)

# %%
from dotenv import load_dotenv
import os
import os

# %%
load_dotenv()
GEMINI_API_KEY = os.getenv('GEMINI_API_KEY')
print(f"GEMINI_API_KEY: {GEMINI_API_KEY}")
# Out:
# GEMINI_API_KEY: AIzaSyAngEbXPsEZ_LWtiyVEXVLBm4LPT_lNQTU

# %%
from google import genai
GEMINI_API_KEY = 'AIzaSyCMOojm7aZCdHsN1n6DKQRj4IWl9J9MuVs'

client = genai.Client(api_key=GEMINI_API_KEY)

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# AI processes data to learn patterns and make decisions or predictions.
